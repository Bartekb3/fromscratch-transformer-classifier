# %%
from getpass import getpass
token = getpass('GitHub token: ')

# %%
# !wandb login

# %%
# !git clone --branch main https://$token@github.com/Bartekb3/fromscratch-transformer-classifier.git

# %%
exp_names = [
    # PRETRAINING
    ("E1_pretraining_wikipedia_bertsmall_mha", "pretraining"),
    ("E1_pretraining_imdb_bertsmall_mha", "pretraining"),
    ("E1_pretraining_hyperpartisan_bertsmall_mha", "pretraining"),
    ("E1_pretraining_arxiv_bertsmall_mha", "pretraining"),

    # FINETUNING – imdb
    ("E1_finetuning_imdb_bertsmall_mha_f0_d0.1_cls", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f0_d0.1_mean", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f0_d0.2_cls", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f0_d0.2_mean", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f1_d0.1_cls", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f1_d0.1_mean", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f1_d0.2_cls", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f1_d0.2_mean", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f2_d0.1_cls", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f2_d0.1_mean", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f2_d0.2_cls", "finetuning"),
    ("E1_finetuning_imdb_bertsmall_mha_f2_d0.2_mean", "finetuning"),

    # FINETUNING – hyperpartisan
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f0_d0.1_cls", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f0_d0.1_mean", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f0_d0.2_cls", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f0_d0.2_mean", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f1_d0.1_cls", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f1_d0.1_mean", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f1_d0.2_cls", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f1_d0.2_mean", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f2_d0.1_cls", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f2_d0.1_mean", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f2_d0.2_cls", "finetuning"),
    ("E1_finetuning_hyperpartisan_bertsmall_mha_f2_d0.2_mean", "finetuning"),

    # FINETUNING – arxiv
    ("E1_finetuning_arxiv_bertsmall_mha_f0_d0.1_cls", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f0_d0.1_mean", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f0_d0.2_cls", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f0_d0.2_mean", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f1_d0.1_cls", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f1_d0.1_mean", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f1_d0.2_cls", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f1_d0.2_mean", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f2_d0.1_cls", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f2_d0.1_mean", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f2_d0.2_cls", "finetuning"),
    ("E1_finetuning_arxiv_bertsmall_mha_f2_d0.2_mean", "finetuning"),
     # PRETRAINING – LSH
    ("E2_pretraining_wikipedia_bertsmall_lsh_h2_c64", "pretraining"),
    ("E2_pretraining_wikipedia_bertsmall_lsh_h2_c128", "pretraining"),
    ("E2_pretraining_wikipedia_bertsmall_lsh_h4_c64", "pretraining"),
    ("E2_pretraining_wikipedia_bertsmall_lsh_h4_c128", "pretraining"),

    ("E2_pretraining_imdb_bertsmall_lsh_h2_c64", "pretraining"),
    ("E2_pretraining_imdb_bertsmall_lsh_h2_c128", "pretraining"),
    ("E2_pretraining_imdb_bertsmall_lsh_h4_c64", "pretraining"),
    ("E2_pretraining_imdb_bertsmall_lsh_h4_c128", "pretraining"),

    ("E2_pretraining_hyperpartisan_bertsmall_lsh_h2_c64", "pretraining"),
    ("E2_pretraining_hyperpartisan_bertsmall_lsh_h2_c128", "pretraining"),
    ("E2_pretraining_hyperpartisan_bertsmall_lsh_h4_c64", "pretraining"),
    ("E2_pretraining_hyperpartisan_bertsmall_lsh_h4_c128", "pretraining"),

    ("E2_pretraining_arxiv_bertsmall_lsh_h2_c64", "pretraining"),
    ("E2_pretraining_arxiv_bertsmall_lsh_h2_c128", "pretraining"),
    ("E2_pretraining_arxiv_bertsmall_lsh_h4_c64", "pretraining"),
    ("E2_pretraining_arxiv_bertsmall_lsh_h4_c128", "pretraining"),

    # PRETRAINING – FAVOR
    ("E2_pretraining_wikipedia_bertsmall_favor_nb1", "pretraining"),
    ("E2_pretraining_wikipedia_bertsmall_favor_nb0.5", "pretraining"),
    ("E2_pretraining_wikipedia_bertsmall_favor_nb0.25", "pretraining"),
    ("E2_pretraining_wikipedia_bertsmall_favor_nb0.125", "pretraining"),

    ("E2_pretraining_imdb_bertsmall_favor_nb1", "pretraining"),
    ("E2_pretraining_imdb_bertsmall_favor_nb0.5", "pretraining"),
    ("E2_pretraining_imdb_bertsmall_favor_nb0.25", "pretraining"),
    ("E2_pretraining_imdb_bertsmall_favor_nb0.125", "pretraining"),

    ("E2_pretraining_hyperpartisan_bertsmall_favor_nb1", "pretraining"),
    ("E2_pretraining_hyperpartisan_bertsmall_favor_nb0.5", "pretraining"),
    ("E2_pretraining_hyperpartisan_bertsmall_favor_nb0.25", "pretraining"),
    ("E2_pretraining_hyperpartisan_bertsmall_favor_nb0.125", "pretraining"),

    ("E2_pretraining_arxiv_bertsmall_favor_nb1", "pretraining"),
    ("E2_pretraining_arxiv_bertsmall_favor_nb0.5", "pretraining"),
    ("E2_pretraining_arxiv_bertsmall_favor_nb0.25", "pretraining"),
    ("E2_pretraining_arxiv_bertsmall_favor_nb0.125", "pretraining"),

    # FINETUNING – LSH 
    ("E2_finetuning_imdb_bertsmall_lsh_h2_c64", "finetuning"),
    ("E2_finetuning_imdb_bertsmall_lsh_h2_c128", "finetuning"),
    ("E2_finetuning_imdb_bertsmall_lsh_h4_c64", "finetuning"),
    ("E2_finetuning_imdb_bertsmall_lsh_h4_c128", "finetuning"),

    ("E2_finetuning_hyperpartisan_bertsmall_lsh_h2_c64", "finetuning"),
    ("E2_finetuning_hyperpartisan_bertsmall_lsh_h2_c128", "finetuning"),
    ("E2_finetuning_hyperpartisan_bertsmall_lsh_h4_c64", "finetuning"),
    ("E2_finetuning_hyperpartisan_bertsmall_lsh_h4_c128", "finetuning"),

    ("E2_finetuning_arxiv_bertsmall_lsh_h2_c64", "finetuning"),
    ("E2_finetuning_arxiv_bertsmall_lsh_h2_c128", "finetuning"),
    ("E2_finetuning_arxiv_bertsmall_lsh_h4_c64", "finetuning"),
    ("E2_finetuning_arxiv_bertsmall_lsh_h4_c128", "finetuning"),

    # FINETUNING – FAVOR
    ("E2_finetuning_imdb_bertsmall_favor_nb1", "finetuning"),
    ("E2_finetuning_imdb_bertsmall_favor_nb0.5", "finetuning"),
    ("E2_finetuning_imdb_bertsmall_favor_nb0.25", "finetuning"),
    ("E2_finetuning_imdb_bertsmall_favor_nb0.125", "finetuning"),

    ("E2_finetuning_hyperpartisan_bertsmall_favor_nb1", "finetuning"),
    ("E2_finetuning_hyperpartisan_bertsmall_favor_nb0.5", "finetuning"),
    ("E2_finetuning_hyperpartisan_bertsmall_favor_nb0.25", "finetuning"),
    ("E2_finetuning_hyperpartisan_bertsmall_favor_nb0.125", "finetuning"),

    ("E2_finetuning_arxiv_bertsmall_favor_nb1", "finetuning"),
    ("E2_finetuning_arxiv_bertsmall_favor_nb0.5", "finetuning"),
    ("E2_finetuning_arxiv_bertsmall_favor_nb0.25", "finetuning"),
    ("E2_finetuning_arxiv_bertsmall_favor_nb0.125", "finetuning"),
]

# %%
# All tokenized datasets must be in google drive data/tokenized directory

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp -r /content/drive/MyDrive/data/tokenized/* /content/fromscratch-transformer-classifier/data/tokenized

# %%
# %cd /content/fromscratch-transformer-classifier

# %%
# !python ./research/exp_generator/generate_experiments.py --exp E1
# !python ./research/exp_generator/generate_experiments.py --exp E2

# %%
for exp_name, mode in exp_names:
    # !python train.py -n "{exp_name}" -m "{mode}"
    # !cp -r /content/fromscratch-transformer-classifier/experiments/{mode}/{exp_name}/checkpoints /content/drive/MyDrive/experiments/{mode}/{exp_name}/
    # !cp -r /content/fromscratch-transformer-classifier/experiments/{mode}/{exp_name}/wandb /content/drive/MyDrive/experiments/{mode}/{exp_name}/
