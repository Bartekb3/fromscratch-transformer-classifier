# %%
from getpass import getpass
token = getpass('GitHub token: ')
# Out:
# GitHub token: ··········

# %%
# !wandb login

# %%
# !git clone --branch main https://$token@github.com/Bartekb3/fromscratch-transformer-classifier.git
# Out:
# Cloning into 'fromscratch-transformer-classifier'...
# remote: Enumerating objects: 1290, done.
# remote: Counting objects: 100% (284/284), done.
# remote: Compressing objects: 100% (168/168), done.
# remote: Total 1290 (delta 147), reused 200 (delta 110), pack-reused 1006 (from 1)
# Receiving objects: 100% (1290/1290), 20.71 MiB | 11.54 MiB/s, done.
# Resolving deltas: 100% (645/645), done.

# %%
exp_names = []
mode = 'pretraining'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/drive/MyDrive/data/tokenized/* /content/fromscratch-transformer-classifier/data/tokenized

# %%
# !cp -r /content/drive/MyDrive/experiments/{mode}/* /content/fromscratch-transformer-classifier/experiments/{mode}/

# %%
# %cd /content/fromscratch-transformer-classifier
# Out:
# /content/fromscratch-transformer-classifier

# %%
for exp_name in exp_names:
    # !python train.py -n "{exp_name}" -m "{mode}"
    # !cp -r /content/fromscratch-transformer-classifier/experiments/{mode}/{exp_name}/checkpoints /content/drive/MyDrive/experiments/{mode}/{exp_name}/
# Out:
# wandb: Currently logged in as: iwaniuk-michal03 (praca-inzynierska) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run hgovz87x (0.2s)
# wandb: ⣽ setting up run hgovz87x (0.2s)
# wandb: ⣾ setting up run hgovz87x (0.2s)
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /content/fromscratch-transformer-classifier/experiments/pretraining/pretraining_wikipedia_autotinys3_sdpa/wandb/run-20251210_084425-hgovz87x
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run pretraining_wikipedia_autotinys3_sdpa
# wandb: ⭐️ View project at https://wandb.ai/praca-inzynierska/text_classification
# wandb: 🚀 View run at https://wandb.ai/praca-inzynierska/text_classification/runs/hgovz87x
# One minute sleep for loading wandb!
# [wandb] Initialized run 'pretraining_wikipedia_autotinys3_sdpa' in project 'text_classification' (praca-inzynierska)
# Epoch: 0
# Traceback (most recent call last):
#   File "/content/fromscratch-transformer-classifier/train.py", line 118, in <module>
#     main(args)
#   File "/content/fromscratch-transformer-classifier/train.py", line 85, in main
#     loop.fit(
#   File "/content/fromscratch-transformer-classifier/src/textclf_transformer/training/training_loop.py", line 363, in fit
#     loss, grad_norm_before_clip, effective_count = self._train_step(
#                                                    ^^^^^^^^^^^^^^^^^
#   File "/content/fromscratch-transformer-classifier/src/textclf_transformer/training/training_loop.py", line 295, in _train_step
#     self.model.parameters(), self.max_grad_norm).item()
#                                                  ^^^^^^
# KeyboardInterrupt
# wandb:
# wandb: 🚀 View run pretraining_wikipedia_autotinys3_sdpa at: https://wandb.ai/praca-inzynierska/text_classification/runs/hgovz87x
# wandb: Find logs at: experiments/pretraining/pretraining_wikipedia_autotinys3_sdpa/wandb/run-20251210_084425-hgovz87x/logs
