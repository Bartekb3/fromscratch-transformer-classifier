# %%
from pathlib import Path
import sys
from torchinfo import summary
import torch
from pathlib import Path

import torch
from src.textclf_transformer.training.training_loop import TrainingLoop
from src.textclf_transformer import *


ROOT = Path().resolve().parents[0]  # one level up from the notebook folder
sys.path.insert(0, str(ROOT))

# %%
EXP_BASE = Path(f'{ROOT}/experiments/pretraining/')
name = 'E3_pretraining_imdb_autotinys1_mha'


exp_dir, cfg = read_experiment_config(EXP_BASE, name)
set_global_seed(cfg["experiment"].get("seed", 42))
wrapper = load_tokenizer_wrapper_from_cfg(cfg["tokenizer"])
arch_kw = arch_kwargs_from_cfg(cfg, wrapper.tokenizer) 
head = cfg["mlm_head"]

# %%
model = TransformerForMaskedLM(
    **arch_kw,
    tie_mlm_weights=head["tie_mlm_weights"]
    )

# %%
model.eval()

B, N = 3, 100
vocab_size, pad_id = arch_kw['vocab_size'], arch_kw['pad_token_id']
device = "cpu"  

input_ids = torch.randint(1, vocab_size, (B, N), dtype=torch.long)
input_ids[:, -4:] = pad_id  
inputs = {
    "input_ids": input_ids,
    "attention_mask": (input_ids == pad_id),            
}

info = summary(
    model,
    input_data=inputs,     
    device=device,
    depth=5,
    #col_names=("input_size", "output_size", "num_params", "mult_adds"),
    col_names=("num_params",),
    verbose=1,
    return_sequence=False,  
)
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# TransformerForMaskedLM                             --
# ├─TransformerTextEmbeddings: 1-1                   --
# │    └─Embedding: 2-1                              17,214,408
# │    └─LayerNorm: 2-2                              1,128
# │    └─Dropout: 2-3                                --
# ├─ModuleList: 1-2                                  --
# │    └─TransformerEncoderBlock: 2-4                --
# │    │    └─AttentionBlock: 3-1                    --
# │    │    │    └─MultiheadSelfAttention: 4-1       --
# │    │    │    │    └─Linear: 5-1                  867,840
# │    │    │    │    └─Linear: 5-2                  289,332
# │    │    │    │    └─Dropout: 5-3                 --
# │    │    │    └─LayerNorm: 4-2                    1,128
# │    │    └─MLPBlock: 3-2                          --
# │    │    │    └─Sequential: 4-3                   --
# │    │    │    │    └─Linear: 5-4                  595,510
# │    │    │    │    └─GELU: 5-5                    --
# │    │    │    │    └─Linear: 5-6                  595,020
# │    │    │    │    └─Dropout: 5-7                 --
# │    │    │    └─LayerNorm: 4-4                    1,128
# │    └─TransformerEncoderBlock: 2-5                --
# │    │    └─AttentionBlock: 3-3                    --
# │    │    │    └─MultiheadSelfAttention: 4-5       --
# │    │    │    │    └─Linear: 5-8                  867,840
# │    │    │    │    └─Linear: 5-9                  289,332
# │    │    │    │    └─Dropout: 5-10                --
# │    │    │    └─LayerNorm: 4-6                    1,128
# │    │    └─MLPBlock: 3-4                          --
# │    │    │    └─Sequential: 4-7                   --
# │    │    │    │    └─Linear: 5-11                 595,510
# │    │    │    │    └─GELU: 5-12                   --
# │    │    │    │    └─Linear: 5-13                 595,020
# │    │    │    │    └─Dropout: 5-14                --
# │    │    │    └─LayerNorm: 4-8                    1,128
# │    └─TransformerEncoderBlock: 2-6                --
# │    │    └─AttentionBlock: 3-5                    --
# │    │    │    └─MultiheadSelfAttention: 4-9       --
# │    │    │    │    └─Linear: 5-15                 867,840
# │    │    │    │    └─Linear: 5-16                 289,332
# │    │    │    │    └─Dropout: 5-17                --
# │    │    │    └─LayerNorm: 4-10                   1,128
# │    │    └─MLPBlock: 3-6                          --
# │    │    │    └─Sequential: 4-11                  --
# │    │    │    │    └─Linear: 5-18                 595,510
# │    │    │    │    └─GELU: 5-19                   --
# │    │    │    │    └─Linear: 5-20                 595,020
# │    │    │    │    └─Dropout: 5-21                --
# │    │    │    └─LayerNorm: 4-12                   1,128
# │    └─TransformerEncoderBlock: 2-7                --
# │    │    └─AttentionBlock: 3-7                    --
# │    │    │    └─MultiheadSelfAttention: 4-13      --
# │    │    │    │    └─Linear: 5-22                 867,840
# │    │    │    │    └─Linear: 5-23                 289,332
# │    │    │    │    └─Dropout: 5-24                --
# │    │    │    └─LayerNorm: 4-14                   1,128
# │    │    └─MLPBlock: 3-8                          --
# │    │    │    └─Sequential: 4-15                  --
# │    │    │    │    └─Linear: 5-25                 595,510
# │    │    │    │    └─GELU: 5-26                   --
# │    │    │    │    └─Linear: 5-27                 595,020
# │    │    │    │    └─Dropout: 5-28                --
# │    │    │    └─LayerNorm: 4-16                   1,128
# │    └─TransformerEncoderBlock: 2-8                --
# │    │    └─AttentionBlock: 3-9                    --
# │    │    │    └─MultiheadSelfAttention: 4-17      --
# │    │    │    │    └─Linear: 5-29                 867,840
# │    │    │    │    └─Linear: 5-30                 289,332
# │    │    │    │    └─Dropout: 5-31                --
# │    │    │    └─LayerNorm: 4-18                   1,128
# │    │    └─MLPBlock: 3-10                         --
# │    │    │    └─Sequential: 4-19                  --
# │    │    │    │    └─Linear: 5-32                 595,510
# │    │    │    │    └─GELU: 5-33                   --
# │    │    │    │    └─Linear: 5-34                 595,020
# │    │    │    │    └─Dropout: 5-35                --
# │    │    │    └─LayerNorm: 4-20                   1,128
# ├─MaskedLanguageModelingHead: 1-3                  --
# │    └─Sequential: 2-9                             --
# │    │    └─Linear: 3-11                           318,660
# │    │    └─GELU: 3-12                             --
# │    │    └─LayerNorm: 3-13                        1,128
# │    └─Linear: 2-10                                17,214,408
# ===========================================================================
# Total params: 46,499,522
# Trainable params: 46,499,522
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 139.50
# ===========================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 136.82
# Params size (MB): 186.00
# Estimated Total Size (MB): 322.82
# ===========================================================================

# %%
EXP_BASE = Path(f'{ROOT}/experiments/finetuning/')
name = 'E3_finetuning_imdb_autotinys1_mha'


exp_dir, cfg = read_experiment_config(EXP_BASE, name)
set_global_seed(cfg["experiment"].get("seed", 42))
wrapper = load_tokenizer_wrapper_from_cfg(cfg["tokenizer"])
arch_kw = arch_kwargs_from_cfg(cfg, wrapper.tokenizer) 
head = cfg['classification_head']

# %%
model = TransformerForSequenceClassification(
    **arch_kw,
    num_labels = head['num_labels'],
    classifier_dropout = head['classifier_dropout'],
    pooling = head['pooling'],
    pooler_type = head['pooler_type'],
    )

# %%
model.eval()

B, N = 3, 100
vocab_size, pad_id = arch_kw['vocab_size'], arch_kw['pad_token_id']
device = "cpu"  

input_ids = torch.randint(1, vocab_size, (B, N), dtype=torch.long)
input_ids[:, -4:] = pad_id  
inputs = {
    "input_ids": input_ids,
    "attention_mask": (input_ids == pad_id),            
}

info = summary(
    model,
    input_data=inputs,     
    device=device,
    depth=3,
    #col_names=("input_size", "output_size", "num_params", "mult_adds"),
    col_names=("num_params",),
    verbose=1,
    return_sequence=False,  
)
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# TransformerForSequenceClassification               --
# ├─TransformerTextEmbeddings: 1-1                   --
# │    └─Embedding: 2-1                              17,214,408
# │    └─LayerNorm: 2-2                              1,128
# │    └─Dropout: 2-3                                --
# ├─ModuleList: 1-2                                  --
# │    └─TransformerEncoderBlock: 2-4                --
# │    │    └─AttentionBlock: 3-1                    1,158,300
# │    │    └─MLPBlock: 3-2                          1,191,658
# │    └─TransformerEncoderBlock: 2-5                --
# │    │    └─AttentionBlock: 3-3                    1,158,300
# │    │    └─MLPBlock: 3-4                          1,191,658
# │    └─TransformerEncoderBlock: 2-6                --
# │    │    └─AttentionBlock: 3-5                    1,158,300
# │    │    └─MLPBlock: 3-6                          1,191,658
# │    └─TransformerEncoderBlock: 2-7                --
# │    │    └─AttentionBlock: 3-7                    1,158,300
# │    │    └─MLPBlock: 3-8                          1,191,658
# │    └─TransformerEncoderBlock: 2-8                --
# │    │    └─AttentionBlock: 3-9                    1,158,300
# │    │    └─MLPBlock: 3-10                         1,191,658
# ├─MeanPooling: 1-3                                 --
# ├─SequenceClassificationHead: 1-4                  --
# │    └─Sequential: 2-9                             --
# │    │    └─Linear: 3-11                           318,660
# │    │    └─Tanh: 3-12                             --
# │    └─Dropout: 2-10                               --
# │    └─Linear: 2-11                                1,130
# ===========================================================================
# Total params: 29,285,116
# Trainable params: 29,285,116
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 87.86
# ===========================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 60.87
# Params size (MB): 117.14
# Estimated Total Size (MB): 178.02
# ===========================================================================
